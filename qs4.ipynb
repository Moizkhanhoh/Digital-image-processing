# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-2de34dcd-5553-406a-b384-1fc32ae6f1f4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2de34dcd-5553-406a-b384-1fc32ae6f1f4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving SanFrancisco.jpg to SanFrancisco.jpg

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

img = cv2.imread('SanFrancisco.jpg',0)
f = np.fft.fft2(img)
fshift = np.fft.fftshift(f)
magnitude_spectrum = 20*np.log(np.abs(fshift))

plt.subplot(121),plt.imshow(img, cmap = 'gray')
plt.title('Input Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(magnitude_spectrum, cmap = 'gray')
plt.title('Magnitude Spectrum'), plt.xticks([]), plt.yticks([])
plt.show()

# %%
 f.shape
# Out:
# (168, 300)

# %%
magnitude_spectrum = 20*np.log(np.abs(fshift))

# %%
f = np.fft.fft2(img)
fshift = np.fft.fftshift(f)
fshift = np.fft.ifftshift(fshift)

# %%
print(magnitude_spectrum)
# Out:
# [[147.06163841 156.8637985  176.65569292 ... 166.55339439 176.65569292
#   156.8637985 ]
#  [147.14406264 152.53226838 170.89529782 ... 170.98070135 175.93484984
#   154.26111563]
#  [160.51914488 150.03860346 168.41458353 ... 163.39954284 172.30613989
#   159.68769626]
#  ...
#  [171.07562402 153.12736709 166.6691679  ... 175.019914   164.99874674
#   165.81228849]
#  [160.51914488 159.68769626 172.30613989 ... 172.32174567 168.41458353
#   150.03860346]
#  [147.14406264 154.26111563 175.93484984 ... 168.13248409 170.89529782
#   152.53226838]]
